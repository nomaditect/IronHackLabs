# %% [markdown]
# # Lab | Hurricane_geo01_20201125

# %%
# assemble packages
import geopandas
import numpy as np
import pandas as pd
from shapely.geometry import Point

import missingno as msn

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
country=geopandas.read_file('/Users/AFROARC/Documents/GitHub/IronHackLabs/Week 6/geospatial/Hurricane/gz_2010_us_040_00_5m.json')

# %%
country.head()
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US02    02      Alaska       570640.950
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  MULTIPOLYGON (((-166.10574 53.98861, -166.0752...
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...

# %%
country.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GEO_ID      52 non-null     object
#  1   STATE       52 non-null     object
#  2   NAME        52 non-null     object
#  3   LSAD        52 non-null     object
#  4   CENSUSAREA  52 non-null     float64
#  5   geometry    52 non-null     geometry
# dtypes: float64(1), geometry(1), object(4)
# memory usage: 2.6+ KB

# %%
type(country)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(country.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
type(country.geometry[1])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
country.plot()
# Out:
# <AxesSubplot:>

# %%
country[country['NAME'].isin(['Alaska','Hawaii']) == False].plot(figsize=(30,20),color='#3B3C6E');

# %%
florence=pd.read_csv('/Users/AFROARC/Documents/GitHub/IronHackLabs/Week 6/geospatial/Hurricane/stormhistory.csv')
florence.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9  18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9  19.0    30  1007
# 2              2  08/30/2018 17:00  12.9  19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1  20.4    30  1007
# 4              3  08/30/2018 23:00  13.2  20.9    35  1007
#
#                 Movement                        Type Name          Received  \
# 0  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2   W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3  W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4  W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
#
#   Forecaster
# 0      Avila
# 1      Avila
# 2      Avila
# 3      Beven
# 4      Beven

# %% [markdown]
# ## Exploratory Data Analysis

# %%
florence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AdvisoryNumber  105 non-null    object
#  1   Date            105 non-null    object
#  2   Lat             105 non-null    float64
#  3   Long            105 non-null    float64
#  4   Wind            105 non-null    int64
#  5   Pres            105 non-null    int64
#  6   Movement        105 non-null    object
#  7   Type            105 non-null    object
#  8   Name            105 non-null    object
#  9   Received        105 non-null    object
#  10  Forecaster      104 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 9.1+ KB

# %%
msn.bar(florence, color='darkolivegreen');

# %%
florence.describe()
# Out:
#               Lat        Long        Wind         Pres
# count  105.000000  105.000000  105.000000   105.000000
# mean    25.931429   56.938095   74.428571   981.571429
# std      7.975917   20.878865   36.560765    22.780667
# min     12.900000   18.400000   25.000000   939.000000
# 25%     18.900000   41.000000   40.000000   956.000000
# 50%     25.100000   60.000000   70.000000   989.000000
# 75%     33.600000   76.400000  105.000000  1002.000000
# max     42.600000   82.900000  140.000000  1008.000000

# %%
florence.drop(['AdvisoryNumber','Forecaster','Received'], axis=1)
florence.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9  18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9  19.0    30  1007
# 2              2  08/30/2018 17:00  12.9  19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1  20.4    30  1007
# 4              3  08/30/2018 23:00  13.2  20.9    35  1007
#
#                 Movement                        Type Name          Received  \
# 0  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2   W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3  W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4  W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
#
#   Forecaster
# 0      Avila
# 1      Avila
# 2      Avila
# 3      Beven
# 4      Beven

# %%
florence['Long'] = 0 - florence['Long']
florence.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9 -18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9 -19.0    30  1007
# 2              2  08/30/2018 17:00  12.9 -19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1 -20.4    30  1007
# 4              3  08/30/2018 23:00  13.2 -20.9    35  1007
#
#                 Movement                        Type Name          Received  \
# 0  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2   W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3  W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4  W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
#
#   Forecaster
# 0      Avila
# 1      Avila
# 2      Avila
# 3      Beven
# 4      Beven

# %%
florence['coordinates'] = florence[['Long','Lat']].values.tolist()
florence.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9 -18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9 -19.0    30  1007
# 2              2  08/30/2018 17:00  12.9 -19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1 -20.4    30  1007
# 4              3  08/30/2018 23:00  13.2 -20.9    35  1007
#
#                 Movement                        Type Name          Received  \
# 0  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2   W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3  W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4  W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
#
#   Forecaster    coordinates
# 0      Avila  [-18.4, 12.9]
# 1      Avila  [-19.0, 12.9]
# 2      Avila  [-19.4, 12.9]
# 3      Beven  [-20.4, 13.1]
# 4      Beven  [-20.9, 13.2]

# %%
florence['coordinates'] = florence['coordinates'].apply(Point)
florence.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9 -18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9 -19.0    30  1007
# 2              2  08/30/2018 17:00  12.9 -19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1 -20.4    30  1007
# 4              3  08/30/2018 23:00  13.2 -20.9    35  1007
#
#                 Movement                        Type Name          Received  \
# 0  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2   W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3  W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4  W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
#
#   Forecaster         coordinates
# 0      Avila  POINT (-18.4 12.9)
# 1      Avila    POINT (-19 12.9)
# 2      Avila  POINT (-19.4 12.9)
# 3      Beven  POINT (-20.4 13.1)
# 4      Beven  POINT (-20.9 13.2)

# %%
type(florence)
# Out:
# pandas.core.frame.DataFrame

# %%
type(florence['coordinates'])
# Out:
# pandas.core.series.Series

# %%
florence = geopandas.GeoDataFrame(florence, geometry='coordinates')
florence.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9 -18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9 -19.0    30  1007
# 2              2  08/30/2018 17:00  12.9 -19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1 -20.4    30  1007
# 4              3  08/30/2018 23:00  13.2 -20.9    35  1007
#
#                 Movement                        Type Name          Received  \
# 0  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1  W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2   W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3  W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4  W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
#
#   Forecaster                 coordinates
# 0      Avila  POINT (-18.40000 12.90000)
# 1      Avila  POINT (-19.00000 12.90000)
# 2      Avila  POINT (-19.40000 12.90000)
# 3      Beven  POINT (-20.40000 13.10000)
# 4      Beven  POINT (-20.90000 13.20000)

# %%
type(florence)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(florence['coordinates'])
# Out:
# geopandas.geoseries.GeoSeries

# %%
florence[florence['Name']=='Six']
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  08/30/2018 11:00  12.9 -18.4    30  1007
# 1             1A  08/30/2018 14:00  12.9 -19.0    30  1007
# 2              2  08/30/2018 17:00  12.9 -19.4    30  1007
# 3             2A  08/30/2018 20:00  13.1 -20.4    30  1007
# 4              3  08/30/2018 23:00  13.2 -20.9    35  1007
# 5             3A  08/31/2018 02:00  13.4 -21.2    35  1007
# 6              4  08/31/2018 05:00  13.6 -21.4    35  1006
# 7             4A  08/31/2018 08:00  13.7 -21.8    35  1006
# 8              5  08/31/2018 11:00  13.7 -22.7    35  1006
# 9             5A  08/31/2018 14:00  13.8 -23.3    35  1006
#
#                   Movement                        Type Name          Received  \
# 0    W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 10:45
# 1    W at 12 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 13:36
# 2     W at 9 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 16:36
# 3    W at 11 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 19:44
# 4    W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/30/2018 22:42
# 5    W at 13 MPH (280 deg)  Potential Tropical Cyclone  Six  08/31/2018 01:42
# 6  WNW at 12 MPH (285 deg)  Potential Tropical Cyclone  Six  08/31/2018 04:39
# 7  WNW at 12 MPH (285 deg)  Potential Tropical Cyclone  Six  08/31/2018 07:33
# 8  WNW at 13 MPH (285 deg)  Potential Tropical Cyclone  Six  08/31/2018 10:38
# 9  WNW at 13 MPH (285 deg)  Potential Tropical Cyclone  Six  08/31/2018 13:33
#
#   Forecaster                 coordinates
# 0      Avila  POINT (-18.40000 12.90000)
# 1      Avila  POINT (-19.00000 12.90000)
# 2      Avila  POINT (-19.40000 12.90000)
# 3      Beven  POINT (-20.40000 13.10000)
# 4      Beven  POINT (-20.90000 13.20000)
# 5       Berg  POINT (-21.20000 13.40000)
# 6       Berg  POINT (-21.40000 13.60000)
# 7      Avila  POINT (-21.80000 13.70000)
# 8      Avila  POINT (-22.70000 13.70000)
# 9      Avila  POINT (-23.30000 13.80000)

# %%
florence.groupby('Name').Type.count()
# Out:
# Name
# FLORENCE     6
# Florence    85
# SIX          4
# Six         10
# Name: Type, dtype: int64

# %%
print("Mean wind speed of Hurricane Florence is {} mph and it can go up to {} mph maximum"
      .format(round(florence.Wind.mean(),4),florence.Wind.max()))
# Out:
# Mean wind speed of Hurricane Florence is 74.4286 mph and it can go up to 140 mph maximum

# %%
florence.plot(figsize=(20,10));

# %%
# Plotting to see the hurricane overlay the US map:
fig, ax = plt.subplots(1, figsize=(30,20))
base = country[country['NAME'].isin(['Alaska','Hawaii']) == False].plot(ax=ax, color='#3B3C6E')

# plotting the hurricane position on top with red color to stand out:
florence.plot(ax=base, color='darkred', marker="*", markersize=10);

# %%
fig, ax = plt.subplots(1,figsize=(20,20))
base = country[country['NAME'].isin(['Alaska','Hawaii']) == False].plot(ax=ax,color='#3B3C6E')
florence.plot(ax=base, column='Wind',marker='<',markersize=10,cmap='cool',label="Wind speed(mph)")
_ = ax.axis('off')
plt.legend()
ax.set_title("Hurricance Florence in US Map", fontsize=25)
plt.savefig('Hurricane_footage.png',bbox_inches='tight');
