# %%
import pandas as pd

# %%
df=pd.read_excel('/Users/AFROARC/Documents/GitHub/IronHackLabs/Week 6/geospatial/london_underground/2017:07LND_UNDG.xls')

# %%
df.head(20)
# Out:
#                number          station  2017entryWeekday  2017entrySaturday  \
# 0                 NaN              NaN               253                 52
# 1   Counts by station              NaN               NaN                NaN
# 2                                  NaN             Entry              Entry
# 3              Number          Station  2017entryWeekday  2017entrySaturday
# 4                 500       Acton Town              9531               6716
# 5                 502          Aldgate             15080               4397
# 6                 503     Aldgate East             22327              16166
# 7                 505         Alperton              4495               3279
# 8                 506         Amersham              3848               1876
# 9                 507            Angel             30413              20944
# 10                508          Archway             15336              10701
# ...
